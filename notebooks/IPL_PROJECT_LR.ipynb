# %% [markdown]
# # IPL WINNER PROBABILITY PREDICTION PROJECT
#
# Dataset has been taken from Kaggle : https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset
#
# #### This notebook has been created to get the following data:
# - Batting Team
# - Bowling Team
# - City
# - Runs Left
# - Balls Left
# - Wickets Out
# - Current Run Rate
# - Required Run Rate
# - Result (Winner)

# %% [markdown]
# ### (1) Load the datasets

# %%
import numpy as np
import pandas as pd

# %%
match_df = pd.read_csv('../data/IPL_Matches_2008_2022.csv')
delivery_df = pd.read_csv('../data/IPL_Ball_by_Ball_2008_2022.csv')

# %%
match_df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
delivery_df.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %% [markdown]
# ### (2) Shape of the dataset

# %%
match_df.shape
# Out:
# (950, 20)

# %%
delivery_df.shape
# Out:
# (225954, 17)

# %% [markdown]
# ### (3) Group by Innings

# %%
total_scores_df = delivery_df.groupby(['ID','innings']).sum()['total_run'].reset_index()
# Out:
# /tmp/ipykernel_4282/1386064346.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_scores_df = delivery_df.groupby(['ID','innings']).sum()['total_run'].reset_index()

# %%
total_scores_df
# Out:
#            ID  innings  total_run
# 0      335982        1        222
# 1      335982        2         82
# 2      335983        1        240
# 3      335983        2        207
# 4      335984        1        129
# ...       ...      ...        ...
# 1923  1312198        2        193
# 1924  1312199        1        157
# 1925  1312199        2        161
# 1926  1312200        1        130
# 1927  1312200        2        133
#
# [1928 rows x 3 columns]

# %% [markdown]
# Group by first innings to get total runs

# %%
total_scores_df = total_scores_df[total_scores_df['innings'] == 1]

# %%
total_scores_df
# Out:
#            ID  innings  total_run
# 0      335982        1        222
# 2      335983        1        240
# 4      335984        1        129
# 6      335985        1        165
# 8      335986        1        110
# ...       ...      ...        ...
# 1918  1304116        1        157
# 1920  1312197        1        188
# 1922  1312198        1        207
# 1924  1312199        1        157
# 1926  1312200        1        130
#
# [950 rows x 3 columns]

# %% [markdown]
# ### (4) Merge on Match_df

# %%
match_df = match_df.merge(total_scores_df[['ID','total_run']], on='ID')

# %%
match_df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision  ...                  WinningTeam    WonBy Margin  method  \
# 0            bat  ...               Gujarat Titans  Wickets    7.0     NaN
# 1          field  ...             Rajasthan Royals  Wickets    7.0     NaN
# 2          field  ...  Royal Challengers Bangalore     Runs   14.0     NaN
# 3          field  ...               Gujarat Titans  Wickets    7.0     NaN
# 4            bat  ...                 Punjab Kings  Wickets    5.0     NaN
# ..           ...  ...                          ...      ...    ...     ...
# 945          bat  ...        Kolkata Knight Riders  Wickets    5.0     NaN
# 946          bat  ...  Royal Challengers Bangalore  Wickets    5.0     NaN
# 947          bat  ...             Delhi Daredevils  Wickets    9.0     NaN
# 948          bat  ...          Chennai Super Kings     Runs   33.0     NaN
# 949        field  ...        Kolkata Knight Riders     Runs  140.0     NaN
#
#     Player_of_Match                                       Team1Players  \
# 0         HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1        JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2        RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3         DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4     Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..              ...                                                ...
# 945       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2 total_run
# 0       Nitin Menon       130
# 1       Nitin Menon       157
# 2          MA Gough       207
# 3         VK Sharma       188
# 4     NA Patwardhan       157
# ..              ...       ...
# 945     K Hariharan       110
# 946       DJ Harper       165
# 947  GA Pratapkumar       129
# 948      SL Shastri       240
# 949     RE Koertzen       222
#
# [950 rows x 21 columns]

# %% [markdown]
# ### (5) Sort the Teams

# %%
match_df['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
teams = [
    'Rajasthan Royals',
    'Royal Challengers Bangalore',
    'Sunrisers Hyderabad',
    'Delhi Capitals',
    'Chennai Super Kings',
    'Gujarat Titans',
    'Lucknow Super Giants',
    'Kolkata Knight Riders',
    'Punjab Kings',
    'Mumbai Indians'
]

# %%
match_df['Team1'] = match_df['Team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['Team2'] = match_df['Team2'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['WinningTeam'] = match_df['WinningTeam'].str.replace('Delhi Daredevils','Delhi Capitals')

match_df['Team1'] = match_df['Team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['Team2'] = match_df['Team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['WinningTeam'] = match_df['WinningTeam'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

match_df['Team1'] = match_df['Team1'].str.replace('Gujarat Lions','Gujarat Titans')
match_df['Team2'] = match_df['Team2'].str.replace('Gujarat Lions','Gujarat Titans')
match_df['WinningTeam'] = match_df['WinningTeam'].str.replace('Gujarat Lions','Gujarat Titans')

match_df['Team1'] = match_df['Team1'].str.replace('Kings XI Punjab','Punjab Kings')
match_df['Team2'] = match_df['Team2'].str.replace('Kings XI Punjab','Punjab Kings')
match_df['WinningTeam'] = match_df['WinningTeam'].str.replace('Kings XI Punjab','Punjab Kings')

# %%
match_df = match_df[match_df['Team1'].isin(teams)]
match_df = match_df[match_df['Team2'].isin(teams)]
match_df = match_df[match_df['WinningTeam'].isin(teams)]

# %%
match_df.shape
# Out:
# (858, 21)

# %%
match_df = match_df[['ID','City','Team1','Team2','WinningTeam','total_run']]

# %%
match_df
# Out:
#           ID        City                        Team1  \
# 0    1312200   Ahmedabad             Rajasthan Royals
# 1    1312199   Ahmedabad  Royal Challengers Bangalore
# 2    1312198     Kolkata  Royal Challengers Bangalore
# 3    1312197     Kolkata             Rajasthan Royals
# 4    1304116      Mumbai          Sunrisers Hyderabad
# ..       ...         ...                          ...
# 945   335986     Kolkata        Kolkata Knight Riders
# 946   335985      Mumbai               Mumbai Indians
# 947   335984       Delhi               Delhi Capitals
# 948   335983  Chandigarh                 Punjab Kings
# 949   335982   Bangalore  Royal Challengers Bangalore
#
#                            Team2                  WinningTeam  total_run
# 0                 Gujarat Titans               Gujarat Titans        130
# 1               Rajasthan Royals             Rajasthan Royals        157
# 2           Lucknow Super Giants  Royal Challengers Bangalore        207
# 3                 Gujarat Titans               Gujarat Titans        188
# 4                   Punjab Kings                 Punjab Kings        157
# ..                           ...                          ...        ...
# 945          Sunrisers Hyderabad        Kolkata Knight Riders        110
# 946  Royal Challengers Bangalore  Royal Challengers Bangalore        165
# 947             Rajasthan Royals               Delhi Capitals        129
# 948          Chennai Super Kings          Chennai Super Kings        240
# 949        Kolkata Knight Riders        Kolkata Knight Riders        222
#
# [858 rows x 6 columns]

# %%
delivery_df
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# 0        JC Buttler        NaN            0           0          0
# 1        JC Buttler    legbyes            0           1          1
# 2       YBK Jaiswal        NaN            1           0          1
# 3        JC Buttler        NaN            0           0          0
# 4        JC Buttler        NaN            0           0          0
# ...             ...        ...          ...         ...        ...
# 225949     SB Joshi    legbyes            0           1          1
# 225950      P Kumar        NaN            1           0          1
# 225951     SB Joshi        NaN            0           0          0
# 225952      P Kumar      wides            0           1          1
# 225953      P Kumar        NaN            0           0          0
#
#         non_boundary  isWicketDelivery player_out    kind fielders_involved  \
# 0                  0                 0        NaN     NaN               NaN
# 1                  0                 0        NaN     NaN               NaN
# 2                  0                 0        NaN     NaN               NaN
# 3                  0                 0        NaN     NaN               NaN
# 4                  0                 0        NaN     NaN               NaN
# ...              ...               ...        ...     ...               ...
# 225949             0                 0        NaN     NaN               NaN
# 225950             0                 0        NaN     NaN               NaN
# 225951             0                 0        NaN     NaN               NaN
# 225952             0                 0        NaN     NaN               NaN
# 225953             0                 1   SB Joshi  caught       BB McCullum
#
#                         BattingTeam
# 0                  Rajasthan Royals
# 1                  Rajasthan Royals
# 2                  Rajasthan Royals
# 3                  Rajasthan Royals
# 4                  Rajasthan Royals
# ...                             ...
# 225949  Royal Challengers Bangalore
# 225950  Royal Challengers Bangalore
# 225951  Royal Challengers Bangalore
# 225952  Royal Challengers Bangalore
# 225953  Royal Challengers Bangalore
#
# [225954 rows x 17 columns]

# %%
delivery_df = match_df.merge(delivery_df, on='ID')

# %%
delivery_df
# Out:
#              ID       City                        Team1  \
# 0       1312200  Ahmedabad             Rajasthan Royals
# 1       1312200  Ahmedabad             Rajasthan Royals
# 2       1312200  Ahmedabad             Rajasthan Royals
# 3       1312200  Ahmedabad             Rajasthan Royals
# 4       1312200  Ahmedabad             Rajasthan Royals
# ...         ...        ...                          ...
# 204767   335982  Bangalore  Royal Challengers Bangalore
# 204768   335982  Bangalore  Royal Challengers Bangalore
# 204769   335982  Bangalore  Royal Challengers Bangalore
# 204770   335982  Bangalore  Royal Challengers Bangalore
# 204771   335982  Bangalore  Royal Challengers Bangalore
#
#                         Team2            WinningTeam  total_run_x  innings  \
# 0              Gujarat Titans         Gujarat Titans          130        1
# 1              Gujarat Titans         Gujarat Titans          130        1
# 2              Gujarat Titans         Gujarat Titans          130        1
# 3              Gujarat Titans         Gujarat Titans          130        1
# 4              Gujarat Titans         Gujarat Titans          130        1
# ...                       ...                    ...          ...      ...
# 204767  Kolkata Knight Riders  Kolkata Knight Riders          222        2
# 204768  Kolkata Knight Riders  Kolkata Knight Riders          222        2
# 204769  Kolkata Knight Riders  Kolkata Knight Riders          222        2
# 204770  Kolkata Knight Riders  Kolkata Knight Riders          222        2
# 204771  Kolkata Knight Riders  Kolkata Knight Riders          222        2
#
#         overs  ballnumber       batter  ... extra_type batsman_run extras_run  \
# 0           0           1  YBK Jaiswal  ...        NaN           0          0
# 1           0           2  YBK Jaiswal  ...    legbyes           0          1
# 2           0           3   JC Buttler  ...        NaN           1          0
# 3           0           4  YBK Jaiswal  ...        NaN           0          0
# 4           0           5  YBK Jaiswal  ...        NaN           0          0
# ...       ...         ...          ...  ...        ...         ...        ...
# 204767     14           5      P Kumar  ...    legbyes           0          1
# 204768     14           6     SB Joshi  ...        NaN           1          0
# 204769     14           7      P Kumar  ...        NaN           0          0
# 204770     15           1     SB Joshi  ...      wides           0          1
# 204771     15           2     SB Joshi  ...        NaN           0          0
#
#         total_run_y  non_boundary  isWicketDelivery  player_out    kind  \
# 0                 0             0                 0         NaN     NaN
# 1                 1             0                 0         NaN     NaN
# 2                 1             0                 0         NaN     NaN
# 3                 0             0                 0         NaN     NaN
# 4                 0             0                 0         NaN     NaN
# ...             ...           ...               ...         ...     ...
# 204767            1             0                 0         NaN     NaN
# 204768            1             0                 0         NaN     NaN
# 204769            0             0                 0         NaN     NaN
# 204770            1             0                 0         NaN     NaN
# 204771            0             0                 1    SB Joshi  caught
#
#        fielders_involved                  BattingTeam
# 0                    NaN             Rajasthan Royals
# 1                    NaN             Rajasthan Royals
# 2                    NaN             Rajasthan Royals
# 3                    NaN             Rajasthan Royals
# 4                    NaN             Rajasthan Royals
# ...                  ...                          ...
# 204767               NaN  Royal Challengers Bangalore
# 204768               NaN  Royal Challengers Bangalore
# 204769               NaN  Royal Challengers Bangalore
# 204770               NaN  Royal Challengers Bangalore
# 204771       BB McCullum  Royal Challengers Bangalore
#
# [204772 rows x 22 columns]

# %%
delivery_df['BattingTeam'] = delivery_df['BattingTeam'].str.replace('Delhi Daredevils','Delhi Capitals')

delivery_df['BattingTeam'] = delivery_df['BattingTeam'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

delivery_df['BattingTeam'] = delivery_df['BattingTeam'].str.replace('Gujarat Lions','Gujarat Titans')

delivery_df['BattingTeam'] = delivery_df['BattingTeam'].str.replace('Kings XI Punjab','Punjab Kings')

# %%
delivery_df = delivery_df[delivery_df['BattingTeam'].isin(teams)]

# %% [markdown]
# Generating Bowling Team column

# %%
def bowl(row):
    if row['Team1'] == row['BattingTeam']:
        return row['Team2']
    else:
        return row['Team1']

# %%
delivery_df['BowlingTeam'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#              ID       City                        Team1  \
# 0       1312200  Ahmedabad             Rajasthan Royals
# 1       1312200  Ahmedabad             Rajasthan Royals
# 2       1312200  Ahmedabad             Rajasthan Royals
# 3       1312200  Ahmedabad             Rajasthan Royals
# 4       1312200  Ahmedabad             Rajasthan Royals
# ...         ...        ...                          ...
# 204767   335982  Bangalore  Royal Challengers Bangalore
# 204768   335982  Bangalore  Royal Challengers Bangalore
# 204769   335982  Bangalore  Royal Challengers Bangalore
# 204770   335982  Bangalore  Royal Challengers Bangalore
# 204771   335982  Bangalore  Royal Challengers Bangalore
#
#                         Team2            WinningTeam  total_run_x  innings  \
# 0              Gujarat Titans         Gujarat Titans          130        1
# 1              Gujarat Titans         Gujarat Titans          130        1
# 2              Gujarat Titans         Gujarat Titans          130        1
# 3              Gujarat Titans         Gujarat Titans          130        1
# 4              Gujarat Titans         Gujarat Titans          130        1
# ...                       ...                    ...          ...      ...
# 204767  Kolkata Knight Riders  Kolkata Knight Riders          222        2
# 204768  Kolkata Knight Riders  Kolkata Knight Riders          222        2
# 204769  Kolkata Knight Riders  Kolkata Knight Riders          222        2
# 204770  Kolkata Knight Riders  Kolkata Knight Riders          222        2
# 204771  Kolkata Knight Riders  Kolkata Knight Riders          222        2
#
#         overs  ballnumber       batter  ... batsman_run extras_run  \
# 0           0           1  YBK Jaiswal  ...           0          0
# 1           0           2  YBK Jaiswal  ...           0          1
# 2           0           3   JC Buttler  ...           1          0
# 3           0           4  YBK Jaiswal  ...           0          0
# 4           0           5  YBK Jaiswal  ...           0          0
# ...       ...         ...          ...  ...         ...        ...
# 204767     14           5      P Kumar  ...           0          1
# 204768     14           6     SB Joshi  ...           1          0
# 204769     14           7      P Kumar  ...           0          0
# 204770     15           1     SB Joshi  ...           0          1
# 204771     15           2     SB Joshi  ...           0          0
#
#        total_run_y  non_boundary  isWicketDelivery  player_out    kind  \
# 0                0             0                 0         NaN     NaN
# 1                1             0                 0         NaN     NaN
# 2                1             0                 0         NaN     NaN
# 3                0             0                 0         NaN     NaN
# 4                0             0                 0         NaN     NaN
# ...            ...           ...               ...         ...     ...
# 204767           1             0                 0         NaN     NaN
# 204768           1             0                 0         NaN     NaN
# 204769           0             0                 0         NaN     NaN
# 204770           1             0                 0         NaN     NaN
# 204771           0             0                 1    SB Joshi  caught
#
#         fielders_involved                  BattingTeam            BowlingTeam
# 0                     NaN             Rajasthan Royals         Gujarat Titans
# 1                     NaN             Rajasthan Royals         Gujarat Titans
# 2                     NaN             Rajasthan Royals         Gujarat Titans
# 3                     NaN             Rajasthan Royals         Gujarat Titans
# 4                     NaN             Rajasthan Royals         Gujarat Titans
# ...                   ...                          ...                    ...
# 204767                NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 204768                NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 204769                NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 204770                NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 204771        BB McCullum  Royal Challengers Bangalore  Kolkata Knight Riders
#
# [204772 rows x 23 columns]

# %% [markdown]
# ### (6) Group by second innings

# %%
delivery_df = delivery_df[delivery_df['innings'] == 2]

# %%
delivery_df
# Out:
#              ID       City                        Team1  \
# 120     1312200  Ahmedabad             Rajasthan Royals
# 121     1312200  Ahmedabad             Rajasthan Royals
# 122     1312200  Ahmedabad             Rajasthan Royals
# 123     1312200  Ahmedabad             Rajasthan Royals
# 124     1312200  Ahmedabad             Rajasthan Royals
# ...         ...        ...                          ...
# 204767   335982  Bangalore  Royal Challengers Bangalore
# 204768   335982  Bangalore  Royal Challengers Bangalore
# 204769   335982  Bangalore  Royal Challengers Bangalore
# 204770   335982  Bangalore  Royal Challengers Bangalore
# 204771   335982  Bangalore  Royal Challengers Bangalore
#
#                         Team2            WinningTeam  total_run_x  innings  \
# 120            Gujarat Titans         Gujarat Titans          130        2
# 121            Gujarat Titans         Gujarat Titans          130        2
# 122            Gujarat Titans         Gujarat Titans          130        2
# 123            Gujarat Titans         Gujarat Titans          130        2
# 124            Gujarat Titans         Gujarat Titans          130        2
# ...                       ...                    ...          ...      ...
# 204767  Kolkata Knight Riders  Kolkata Knight Riders          222        2
# 204768  Kolkata Knight Riders  Kolkata Knight Riders          222        2
# 204769  Kolkata Knight Riders  Kolkata Knight Riders          222        2
# 204770  Kolkata Knight Riders  Kolkata Knight Riders          222        2
# 204771  Kolkata Knight Riders  Kolkata Knight Riders          222        2
#
#         overs  ballnumber        batter  ... batsman_run extras_run  \
# 120         0           1       WP Saha  ...           0          0
# 121         0           2       WP Saha  ...           0          0
# 122         0           3       WP Saha  ...           1          0
# 123         0           4  Shubman Gill  ...           0          0
# 124         0           5  Shubman Gill  ...           0          0
# ...       ...         ...           ...  ...         ...        ...
# 204767     14           5       P Kumar  ...           0          1
# 204768     14           6      SB Joshi  ...           1          0
# 204769     14           7       P Kumar  ...           0          0
# 204770     15           1      SB Joshi  ...           0          1
# 204771     15           2      SB Joshi  ...           0          0
#
#        total_run_y  non_boundary  isWicketDelivery  player_out    kind  \
# 120              0             0                 0         NaN     NaN
# 121              0             0                 0         NaN     NaN
# 122              1             0                 0         NaN     NaN
# 123              0             0                 0         NaN     NaN
# 124              0             0                 0         NaN     NaN
# ...            ...           ...               ...         ...     ...
# 204767           1             0                 0         NaN     NaN
# 204768           1             0                 0         NaN     NaN
# 204769           0             0                 0         NaN     NaN
# 204770           1             0                 0         NaN     NaN
# 204771           0             0                 1    SB Joshi  caught
#
#         fielders_involved                  BattingTeam            BowlingTeam
# 120                   NaN               Gujarat Titans       Rajasthan Royals
# 121                   NaN               Gujarat Titans       Rajasthan Royals
# 122                   NaN               Gujarat Titans       Rajasthan Royals
# 123                   NaN               Gujarat Titans       Rajasthan Royals
# 124                   NaN               Gujarat Titans       Rajasthan Royals
# ...                   ...                          ...                    ...
# 204767                NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 204768                NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 204769                NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 204770                NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 204771        BB McCullum  Royal Challengers Bangalore  Kolkata Knight Riders
#
# [98874 rows x 23 columns]

# %% [markdown]
# ### (7) Generate required columns for prediction

# %% [markdown]
# Current Score

# %%
delivery_df['current_score'] = delivery_df.groupby('ID').cumsum()['total_run_y']
# Out:
# /tmp/ipykernel_4282/3325906612.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   delivery_df['current_score'] = delivery_df.groupby('ID').cumsum()['total_run_y']
# /tmp/ipykernel_4282/3325906612.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['current_score'] = delivery_df.groupby('ID').cumsum()['total_run_y']

# %% [markdown]
# Runs Left

# %%
delivery_df['runs_left'] = delivery_df['total_run_x'] - delivery_df['current_score']+1
# Out:
# /tmp/ipykernel_4282/4148514409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['runs_left'] = delivery_df['total_run_x'] - delivery_df['current_score']+1

# %% [markdown]
# Balls Left

# %%
delivery_df['balls_left'] = 120 - (delivery_df['overs']*6 + delivery_df['ballnumber'])
# Out:
# /tmp/ipykernel_4282/1931403187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['balls_left'] = 120 - (delivery_df['overs']*6 + delivery_df['ballnumber'])

# %% [markdown]
# Wickets Left

# %%
wickets = delivery_df.groupby('ID').cumsum()['isWicketDelivery'].values
delivery_df['wickets'] = 10 - wickets
# Out:
# /tmp/ipykernel_4282/1411168926.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   wickets = delivery_df.groupby('ID').cumsum()['isWicketDelivery'].values
# /tmp/ipykernel_4282/1411168926.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['wickets'] = 10 - wickets

# %% [markdown]
# Current Run Rate

# %%
# current_run_rate = runs/overs
delivery_df['current_run_rate'] = (delivery_df['current_score']*6)/(120 - delivery_df['balls_left'])
# Out:
# /tmp/ipykernel_4282/1251681764.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['current_run_rate'] = (delivery_df['current_score']*6)/(120 - delivery_df['balls_left'])

# %% [markdown]
# Required Run Rate

# %%
# required_run_rate = runs_left/overs_left
delivery_df['required_run_rate'] = (delivery_df['runs_left']*6)/delivery_df['balls_left']
# Out:
# /tmp/ipykernel_4282/4238007078.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['required_run_rate'] = (delivery_df['runs_left']*6)/delivery_df['balls_left']

# %% [markdown]
# Result (Winner)

# %%
def result(row):
    if row['BattingTeam'] == row['WinningTeam']:
        return 1 
    else:
        return 0

# %%
delivery_df['Result'] = delivery_df.apply(result,axis=1)
# Out:
# /tmp/ipykernel_4282/2052643436.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['Result'] = delivery_df.apply(result,axis=1)

# %%
delivery_df
# Out:
#              ID       City                        Team1  \
# 120     1312200  Ahmedabad             Rajasthan Royals
# 121     1312200  Ahmedabad             Rajasthan Royals
# 122     1312200  Ahmedabad             Rajasthan Royals
# 123     1312200  Ahmedabad             Rajasthan Royals
# 124     1312200  Ahmedabad             Rajasthan Royals
# ...         ...        ...                          ...
# 204767   335982  Bangalore  Royal Challengers Bangalore
# 204768   335982  Bangalore  Royal Challengers Bangalore
# 204769   335982  Bangalore  Royal Challengers Bangalore
# 204770   335982  Bangalore  Royal Challengers Bangalore
# 204771   335982  Bangalore  Royal Challengers Bangalore
#
#                         Team2            WinningTeam  total_run_x  innings  \
# 120            Gujarat Titans         Gujarat Titans          130        2
# 121            Gujarat Titans         Gujarat Titans          130        2
# 122            Gujarat Titans         Gujarat Titans          130        2
# 123            Gujarat Titans         Gujarat Titans          130        2
# 124            Gujarat Titans         Gujarat Titans          130        2
# ...                       ...                    ...          ...      ...
# 204767  Kolkata Knight Riders  Kolkata Knight Riders          222        2
# 204768  Kolkata Knight Riders  Kolkata Knight Riders          222        2
# 204769  Kolkata Knight Riders  Kolkata Knight Riders          222        2
# 204770  Kolkata Knight Riders  Kolkata Knight Riders          222        2
# 204771  Kolkata Knight Riders  Kolkata Knight Riders          222        2
#
#         overs  ballnumber        batter  ... fielders_involved  \
# 120         0           1       WP Saha  ...               NaN
# 121         0           2       WP Saha  ...               NaN
# 122         0           3       WP Saha  ...               NaN
# 123         0           4  Shubman Gill  ...               NaN
# 124         0           5  Shubman Gill  ...               NaN
# ...       ...         ...           ...  ...               ...
# 204767     14           5       P Kumar  ...               NaN
# 204768     14           6      SB Joshi  ...               NaN
# 204769     14           7       P Kumar  ...               NaN
# 204770     15           1      SB Joshi  ...               NaN
# 204771     15           2      SB Joshi  ...       BB McCullum
#
#                         BattingTeam            BowlingTeam  current_score  \
# 120                  Gujarat Titans       Rajasthan Royals              0
# 121                  Gujarat Titans       Rajasthan Royals              0
# 122                  Gujarat Titans       Rajasthan Royals              1
# 123                  Gujarat Titans       Rajasthan Royals              1
# 124                  Gujarat Titans       Rajasthan Royals              1
# ...                             ...                    ...            ...
# 204767  Royal Challengers Bangalore  Kolkata Knight Riders             80
# 204768  Royal Challengers Bangalore  Kolkata Knight Riders             81
# 204769  Royal Challengers Bangalore  Kolkata Knight Riders             81
# 204770  Royal Challengers Bangalore  Kolkata Knight Riders             82
# 204771  Royal Challengers Bangalore  Kolkata Knight Riders             82
#
#         runs_left  balls_left  wickets  current_run_rate required_run_rate  \
# 120           131         119       10          0.000000          6.605042
# 121           131         118       10          0.000000          6.661017
# 122           130         117       10          2.000000          6.666667
# 123           130         116       10          1.500000          6.724138
# 124           130         115       10          1.200000          6.782609
# ...           ...         ...      ...               ...               ...
# 204767        143          31        1          5.393258         27.677419
# 204768        142          30        1          5.400000         28.400000
# 204769        142          29        1          5.340659         29.379310
# 204770        141          29        1          5.406593         29.172414
# 204771        141          28        0          5.347826         30.214286
#
#        Result
# 120         1
# 121         1
# 122         1
# 123         1
# 124         1
# ...       ...
# 204767      0
# 204768      0
# 204769      0
# 204770      0
# 204771      0
#
# [98874 rows x 30 columns]

# %% [markdown]
# ### (8) Creating the required Dataframe

# %%
ultimate_df = delivery_df[['BattingTeam','BowlingTeam','City','runs_left','balls_left','wickets','total_run_x','current_run_rate','required_run_rate','Result']]

# %%
ultimate_df
# Out:
#                         BattingTeam            BowlingTeam       City  \
# 120                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 121                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 122                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 123                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 124                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# ...                             ...                    ...        ...
# 204767  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 204768  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 204769  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 204770  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 204771  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
#
#         runs_left  balls_left  wickets  total_run_x  current_run_rate  \
# 120           131         119       10          130          0.000000
# 121           131         118       10          130          0.000000
# 122           130         117       10          130          2.000000
# 123           130         116       10          130          1.500000
# 124           130         115       10          130          1.200000
# ...           ...         ...      ...          ...               ...
# 204767        143          31        1          222          5.393258
# 204768        142          30        1          222          5.400000
# 204769        142          29        1          222          5.340659
# 204770        141          29        1          222          5.406593
# 204771        141          28        0          222          5.347826
#
#         required_run_rate  Result
# 120              6.605042       1
# 121              6.661017       1
# 122              6.666667       1
# 123              6.724138       1
# 124              6.782609       1
# ...                   ...     ...
# 204767          27.677419       0
# 204768          28.400000       0
# 204769          29.379310       0
# 204770          29.172414       0
# 204771          30.214286       0
#
# [98874 rows x 10 columns]

# %% [markdown]
# ### (9) Checking for anomalies

# %%
ultimate_df = ultimate_df.sample(ultimate_df.shape[0])

# %%
ultimate_df.sample()
# Out:
#           BattingTeam   BowlingTeam        City  runs_left  balls_left  \
# 77911  Gujarat Titans  Punjab Kings  Chandigarh         99          66
#
#        wickets  total_run_x  current_run_rate  required_run_rate  Result
# 77911       10          189         10.111111                9.0       1

# %%
ultimate_df.isnull().sum()
# Out:
# BattingTeam             0
# BowlingTeam             0
# City                 6012
# runs_left               0
# balls_left              0
# wickets                 0
# total_run_x             0
# current_run_rate        0
# required_run_rate      11
# Result                  0
# dtype: int64

# %%
ultimate_df.describe()
# Out:
#           runs_left    balls_left       wickets   total_run_x  \
# count  98874.000000  98874.000000  98874.000000  98874.000000
# mean      93.145670     62.804246      7.541851    165.404656
# std       49.965384     33.406357      2.152188     28.851342
# min      -15.000000     -3.000000      0.000000     67.000000
# 25%       54.000000     35.000000      6.000000    147.000000
# 50%       92.000000     64.000000      8.000000    165.000000
# 75%      131.000000     92.000000      9.000000    185.000000
# max      249.000000    119.000000     10.000000    248.000000
#
#        current_run_rate  required_run_rate        Result
# count      98874.000000       9.886300e+04  98874.000000
# mean           7.455195                NaN      0.531363
# std            2.262087                NaN      0.499018
# min            0.000000               -inf      0.000000
# 25%            6.292683       7.200000e+00      0.000000
# 50%            7.500000       8.921739e+00      1.000000
# 75%            8.700000       1.101221e+01      1.000000
# max           36.000000                inf      1.000000

# %%
ultimate_df = ultimate_df[ultimate_df['balls_left'] != 0]

# %%
ultimate_df.describe()
# Out:
#           runs_left    balls_left       wickets   total_run_x  \
# count  98544.000000  98544.000000  98544.000000  98544.000000
# mean      93.389582     63.014562      7.557416    165.362376
# std       49.859196     33.263626      2.136848     28.857047
# min      -15.000000     -3.000000      0.000000     67.000000
# 25%       54.000000     35.000000      6.000000    147.000000
# 50%       93.000000     64.000000      8.000000    165.000000
# 75%      131.000000     92.000000      9.000000    185.000000
# max      249.000000    119.000000     10.000000    248.000000
#
#        current_run_rate  required_run_rate        Result
# count      98544.000000       98544.000000  98544.000000
# mean           7.453584          10.505325      0.532706
# std            2.264681          14.109256      0.498932
# min            0.000000        -516.000000      0.000000
# 25%            6.288462           7.200000      0.000000
# 50%            7.500000           8.914286      1.000000
# 75%            8.700000          10.986190      1.000000
# max           36.000000         714.000000      1.000000

# %%
ultimate_df.isnull().sum()
# Out:
# BattingTeam             0
# BowlingTeam             0
# City                 5990
# runs_left               0
# balls_left              0
# wickets                 0
# total_run_x             0
# current_run_rate        0
# required_run_rate       0
# Result                  0
# dtype: int64

# %%
ultimate_df.dropna(inplace=True)

# %%
ultimate_df.isnull().sum()
# Out:
# BattingTeam          0
# BowlingTeam          0
# City                 0
# runs_left            0
# balls_left           0
# wickets              0
# total_run_x          0
# current_run_rate     0
# required_run_rate    0
# Result               0
# dtype: int64

# %%
ultimate_df.shape
# Out:
# (92554, 10)

# %%
ultimate_df['City'].unique()
# Out:
# array(['Kolkata', 'Chandigarh', 'Pune', 'Bangalore', 'Johannesburg',
#        'Hyderabad', 'Chennai', 'Mumbai', 'Delhi', 'Dubai', 'Kanpur',
#        'Centurion', 'Durban', 'Abu Dhabi', 'Bengaluru', 'Jaipur',
#        'Sharjah', 'Rajkot', 'Navi Mumbai', 'Dharamsala', 'Ahmedabad',
#        'Port Elizabeth', 'Kimberley', 'Visakhapatnam', 'Ranchi', 'Nagpur',
#        'Cape Town', 'Cuttack', 'Indore', 'East London', 'Raipur',
#        'Bloemfontein'], dtype=object)

# %%
ultimate_df['City'] = ultimate_df['City'].str.replace('Bangalore','Bengaluru')
ultimate_df['City'] = ultimate_df['City'].str.replace('Dharamsala','Dharamshala')

# %%
ultimate_df.to_csv('../data/IPL_dataset.csv',index=False)

# %% [markdown]
# ### (10) Split the dataset into train and test datasets

# %%
X = ultimate_df.iloc[:,:-1]
Y = ultimate_df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=1)

# %% [markdown]
# ### (11) One Hot Encoder

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['BattingTeam','BowlingTeam','City'])
]
,remainder='passthrough')

# %% [markdown]
# ### (12) Building the pipeline

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,Y_train)
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['BattingTeam', 'BowlingTeam',
#                                                    'City'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
Y_pred = pipe.predict(X_test)

# %% [markdown]
# ### (13) Checking the accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,Y_pred)
# Out:
# 0.80919453298039

# %%
pipe.predict_proba(X_test)[0]
# Out:
# array([0.75096944, 0.24903056])

# %% [markdown]
# ### (14) Send to pickle file

# %%
import pickle
pickle.dump(pipe,open('iplpipe.pkl','wb'))

# %% [markdown]
# Extras

# %%
ultimate_df['City'].unique()
# Out:
# array(['Kolkata', 'Chandigarh', 'Pune', 'Bengaluru', 'Johannesburg',
#        'Hyderabad', 'Chennai', 'Mumbai', 'Delhi', 'Dubai', 'Kanpur',
#        'Centurion', 'Durban', 'Abu Dhabi', 'Jaipur', 'Sharjah', 'Rajkot',
#        'Navi Mumbai', 'Dharamshala', 'Ahmedabad', 'Port Elizabeth',
#        'Kimberley', 'Visakhapatnam', 'Ranchi', 'Nagpur', 'Cape Town',
#        'Cuttack', 'Indore', 'East London', 'Raipur', 'Bloemfontein'],
#       dtype=object)

# %%
ultimate_df['BattingTeam'].unique()
# Out:
# array(['Mumbai Indians', 'Punjab Kings', 'Rajasthan Royals',
#        'Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Delhi Capitals', 'Kolkata Knight Riders', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants'], dtype=object)
